# %% [markdown]
# # Results Analysis
#
# Run the project experiments and inspect generated probabilities/plots.

# %%
from src.zeno_circuit import zeno_sweep
m, p = zeno_sweep(n_steps=100, max_measurements=10, shots=1024)
list(zip(m, p))
